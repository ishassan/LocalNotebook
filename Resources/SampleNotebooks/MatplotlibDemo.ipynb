# %% [markdown]
# # Matplotlib Demo
#
# Run the cell below to render a chart as an image output.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [1, 4, 9])
plt.title('Quadratic Growth')
plt.show()
